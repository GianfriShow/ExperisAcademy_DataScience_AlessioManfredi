# %% [markdown]
# <img src="https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png" alt="500" width="550" align="left"/>

# %%
import pandas as pd

# %%
a = [1, 7, 2]

myvar = pd.Series(a)  # auto-labelled with indices by default

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print(myvar[0])
# Out:
# 1

# %%
a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])  # we can customize the labels (indices)

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 7

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index=["Mon","Tue","Wed"])  # create a dataframe object from a dictionary: each key is a column variable, and each value is the rows in that column

print(df)
# Out:
#      calories  duration
# Mon       420        50
# Tue       380        40
# Wed       390        45

# %% [markdown]
# <img src="https://miro.medium.com/max/1050/1*CgAWzayEQY8PQuMpRkSGfQ.png" alt="500" width="650" align="left"/>

# %%
print(df.iloc[0])  # iloc refers to the standard numerical indices (0,1,2,...)
# Out:
# calories    420
# duration     50
# Name: Mon, dtype: int64

# %%
print(df.loc["Mon"])  # loc refers to the customized labels if we added them
# Out:
# calories    420
# duration     50
# Name: Mon, dtype: int64

# %%
data = {
  "calories": [420, 380, 390, 342, 653, 281],
  "duration": [50, 40, 45, 43, 23, 94]
}
df = pd.DataFrame(data)

# %%
df.head()  # first few rows
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 3       342        43
# 4       653        23

# %%
df.head(6)  # specify how many rows to show
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 3       342        43
# 4       653        23
# 5       281        94

# %%
df.iloc[0, :]
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
df.iloc[0:2]
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
df.iloc[:, 0]
# Out:
# 0    420
# 1    380
# 2    390
# 3    342
# 4    653
# 5    281
# Name: calories, dtype: int64

# %%
df.loc[0, 'calories']
# Out:
# 420

# %%
df.loc[:,'duration']
# Out:
# 0    50
# 1    40
# 2    45
# 3    43
# 4    23
# 5    94
# Name: duration, dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
df = pd.read_csv('test.csv')  # read a csv file and automatically create a dataframe from it (read_excel if we have an excel etc.)
# we can add index_col to specify which column has the indices in the file

print(df)  # read_csv automatically considers the first row as the column names
# Out:
#      name     surname  age
# 0  thomas  bellington   21
# 1  robert      janish   34
# 2  alfred       green   46

# %%
Biodata = {'Name': ['John', 'Emily', 'Mike', 'Lisa'],
        'Age': [28, 23, 35, 31],
        'Gender': ['M', 'F', 'M', 'F']
        }
df = pd.DataFrame(Biodata)

df.to_csv('Biodata.csv', index=False)  # save the dataframe to a CSV file (to_excel to convert to excel file etc.)

# %%
Biodata = {'Name': ['John', 'Emily', 'Mike', 'Lisa'],
        'Age': [28, 23, 17, 31],
        'Gender': ['M', 'F', 'M', 'F']
        }
df = pd.DataFrame(Biodata)

def verify_adult(num):
    if num<18:
        return "Underage"
    else:
        return "Adult"

df['Adult'] = df['Age'].apply(verify_adult)  # add a new column 'Adult' in the dataframe based on which ages satisfy the condition in the apply()

df
# Out:
#     Name  Age Gender     Adult
# 0   John   28      M     Adult
# 1  Emily   23      F     Adult
# 2   Mike   17      M  Underage
# 3   Lisa   31      F     Adult

# %%
# normal function
def square(x):
    return x * x

# lambda function
lambda_square = lambda x : x * x
                 #lambda argument: expression to return

square(5)
lambda_square(5)

(lambda x : x * x)(5)  # compact version of a lambda function, without pre-assigning the function  -->  (lambda function)(arguments)
# this compact method does NOT save the function in memory, it's just temporary in that line
# Out:
# 25

# %%
# more advanced uses of lambda functions
def myfunc(n):
    return lambda a : a * n

double = myfunc(2)

triple = myfunc(3)

# %%
print(double(5))
# Out:
# 10

# %%
print(triple(5))
# Out:
# 15

# %%
z = lambda x,y : x*y + 1  # lambda functions can take multiple arguments like normal functions

print(z(2,3))
# Out:
# 7

# %%
Biodata = {'Name': ['John', 'Emily', 'Mike', 'Lisa'],
        'Age': [28, 23, 17, 31],
        'Gender': ['M', 'F', 'M', 'F']
        }
df = pd.DataFrame(Biodata)

# pass function to apply to create new column
df['Adult'] = df['Age'].apply(lambda x : "Underage" if x < 18 else "Adult")

df
# Out:
#     Name  Age Gender     Adult
# 0   John   28      M     Adult
# 1  Emily   23      F     Adult
# 2   Mike   17      M  Underage
# 3   Lisa   31      F     Adult

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()  # first 5 rows by default
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()  # last 5 rows by default
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'].value_counts()  # frequency stats
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df[['Name', 'Survived']]  # select given columns
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %%
df.describe()  # descriptive statistics
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull()  # returns boolean in cells to indicate if a value is missing
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()  # sum all these booleans, therefore checking how many missing values there are
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin', axis=1, inplace=True)  # drop the column 'Cabin', inplace=True means that the original dataframe is modified (so BE CAREFUL)

# %%
df.head()  # no more 'Cabin' variable
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# to drop multiple columns
# df.drop(columns = [column_1_name, column_2_name], axis=1, inplace=True)

# %%
# with inplace=False, we need to store the output if we want to keep it since the original dataframe is NOT modified
df = df.drop(columns=['Ticket', 'Embarked'], axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare
# 0      0   7.2500
# 1      0  71.2833
# 2      0   7.9250
# 3      0  53.1000
# 4      0   8.0500

# %%
df2 = df.drop(columns = ['Name','Sex'], axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare
# 0      0   7.2500
# 1      0  71.2833
# 2      0   7.9250
# 3      0  53.1000
# 4      0   8.0500

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
df2.corr()  # correlation plot
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = df2.corr()

fig, ax = plt.subplots(figsize=(16, 6))

sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0, annot=True,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
# produce a heatmap representing the correlation plot
# Out:
# <Axes: >
